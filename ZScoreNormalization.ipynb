# %% [markdown]
# <a href="https://colab.research.google.com/github/egomet/zscore-KartikPaliwal18/blob/main/ZScoreNormalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice Notebook
#
# This notebook is the practice location to code-along various programs

# %%
import numpy as np
import scipy.stats as stats

# %%
def normalize(arr):
  arr = np.array(arr)

  # Write your solution here
  mu = ...
  sigma = ...
  arr = (arr - ...)/(...)
  #----------------

  return arr.tolist()
